# %% [markdown]
# <a href="https://colab.research.google.com/github/Temur0122/Pandas_tutorial/blob/main/2_Pandas_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data ={
    'Yil' : [2021,2020,2019,2018,2017,2016,2015,2010],
    'Aholi soni' :[33.9, 33.5, 33.6, 33.2, 35.6, 33.1, 33.7, 33],
    'Temp':[1.54, 1.26, 1.32, 1.27, 1.96, 1.65, 1.56, 1.42]
      }
df = pd.DataFrame(data)

# %%
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.26
# 2  2019        33.6  1.32
# 3  2018        33.2  1.27
# 4  2017        35.6  1.96
# 5  2016        33.1  1.65
# 6  2015        33.7  1.56
# 7  2010        33.0  1.42

# %%
df.head(3)
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.26
# 2  2019        33.6  1.32

# %%
df.shape
# Out:
# (8, 3)

# %%
df =pd.DataFrame(data, columns = ['Yil', 'Temp','Aholi soni'])
df
# Out:
#     Yil  Temp  Aholi soni
# 0  2021  1.54        33.9
# 1  2020  1.26        33.5
# 2  2019  1.32        33.6
# 3  2018  1.27        33.2
# 4  2017  1.96        35.6
# 5  2016  1.65        33.1
# 6  2015  1.56        33.7
# 7  2010  1.42        33.0

# %%
df =pd.DataFrame(data, columns = ['Yil', 'Temp','Aholi soni', 'YAIM'], index = ['a','b', 'c', 'd', 'e', 'f', 'g', 'h'])
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# a  2021  1.54        33.9  NaN
# b  2020  1.26        33.5  NaN
# c  2019  1.32        33.6  NaN
# d  2018  1.27        33.2  NaN
# e  2017  1.96        35.6  NaN
# f  2016  1.65        33.1  NaN
# g  2015  1.56        33.7  NaN
# h  2010  1.42        33.0  NaN

# %%
aholi = df['Aholi soni']
aholi
# Out:
# a    33.9
# b    33.5
# c    33.6
# d    33.2
# e    35.6
# f    33.1
# g    33.7
# h    33.0
# Name: Aholi soni, dtype: float64

# %%
type(aholi)
# Out:
# pandas.core.series.Series

# %%
df.YAIM = 0

# %%
df
# Out:
#     Yil  Temp  Aholi soni  YAIM
# a  2021  1.54        33.9     0
# b  2020  1.26        33.5     0
# c  2019  1.32        33.6     0
# d  2018  1.27        33.2     0
# e  2017  1.96        35.6     0
# f  2016  1.65        33.1     0
# g  2015  1.56        33.7     0
# h  2010  1.42        33.0     0

# %%
val = pd.Series([1700, 1500,1300], index = ['a', 'b', 'h'])
df.YAIM = val
df
# Out:
#     Yil  Temp  Aholi soni    YAIM
# a  2021  1.54        33.9  1700.0
# b  2020  1.26        33.5  1500.0
# c  2019  1.32        33.6     NaN
# d  2018  1.27        33.2     NaN
# e  2017  1.96        35.6     NaN
# f  2016  1.65        33.1     NaN
# g  2015  1.56        33.7     NaN
# h  2010  1.42        33.0  1300.0

# %%
indeks = df.columns
indeks
# Out:
# Index(['Yil', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
'Temp' in indeks
# Out:
# True

# %%
df = pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.26
# 2  2019        33.6  1.32
# 3  2018        33.2  1.27
# 4  2017        35.6  1.96
# 5  2016        33.1  1.65
# 6  2015        33.7  1.56
# 7  2010        33.0  1.42

# %%
usernames = {"Anvar":"Anvarbek223", "Olim":"Olimtoy", "Maryam":"Mary334455", "Javohir":"Javohir445"}
emails = {"Anvar":"anvar@gmail.com", "Olim":"olim@gmail.com", "Maryam":"mary33@gmail.com","Javohir":"javohir445@gmail.com"}

data ={
    'username':usernames ,
    'email':emails
}
df = pd.DataFrame(data)
df
# Out:
#             username                 email
# Anvar    Anvarbek223       anvar@gmail.com
# Olim         Olimtoy        olim@gmail.com
# Maryam    Mary334455      mary33@gmail.com
# Javohir   Javohir445  javohir445@gmail.com

# %%
df.index
# Out:
# Index(['Anvar', 'Olim', 'Maryam', 'Javohir'], dtype='object')

# %%
arr = ['Anvar', 'Olim', 'Maryam', 'Javohir']
arr[0]
# Out:
# 'Anvar'

# %%
data2 ={
    'username':{"Olim":"olimjon21", "Maryam":"maryam2021"},
    'email':{"Olim":"olim21@mail.ru", "Maryam":"maryam20@mail.ru"}
}

# %%
df2 = df.append(pd.DataFrame(data2))
df2
# Out:
# <ipython-input-27-aa695d280860>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df.append(pd.DataFrame(data2))
#             username                 email
# Anvar    Anvarbek223       anvar@gmail.com
# Olim         Olimtoy        olim@gmail.com
# Maryam    Mary334455      mary33@gmail.com
# Javohir   Javohir445  javohir445@gmail.com
# Olim       olimjon21        olim21@mail.ru
# Maryam    maryam2021      maryam20@mail.ru

# %%
newind =pd.Index(["Olim",'nafisa','nafosat'])
newind
# Out:
# Index(['Olim', 'nafisa', 'nafosat'], dtype='object')

# %%
newind.isin(df2.index)
# Out:
# array([ True, False, False])

# %%
df2.index.difference(newind)
# Out:
# Index(['Anvar', 'Javohir', 'Maryam'], dtype='object')

# %%
newind.difference(df2.index)
# Out:
# Index(['nafisa', 'nafosat'], dtype='object')

# %%
df2.index.union(newind)
# Out:
# Index(['Anvar', 'Javohir', 'Maryam', 'Maryam', 'Olim', 'Olim', 'nafisa',
#        'nafosat'],
#       dtype='object')

# %%
df2.index.delete(0)
# Out:
# Index(['Olim', 'Maryam', 'Javohir', 'Olim', 'Maryam'], dtype='object')

# %%
newind.drop('nafosat')
# Out:
# Index(['Olim', 'nafisa'], dtype='object')
